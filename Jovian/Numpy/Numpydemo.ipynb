# %%
print("hello, world!")
# Out:
# hello, world!

# %%
kanto = [73, 67, 43]
johto = [ 91, 88, 64]
hoenn = [87, 134, 58]
sinnoh  = [102, 43, 37]
unova = [69, 96, 70]

# %%
t = "test string!"

# %%
w1, w2, w3 = 0.3, 0.2, 0.5
weights = [w1, w2, w3]

# %%
# %connect_info
# Out:
# {
#   "shell_port": 51792,
#   "iopub_port": 51793,
#   "stdin_port": 51794,
#   "control_port": 51796,
#   "hb_port": 51795,
#   "ip": "127.0.0.1",
#   "key": "ba633f0b-b2a0f6da333e81e4290b94db",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": "python3",
#   "jupyter_session": "C:\\Users\\Anil Krishna\\anikris\\Numpydemo-946b14d4-92d9-46fe-81a0-848484edfbe8.ipynb"
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-86836d77-6eac-4519-ab76-75c1dfeb05ff.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.

# %%
def crop_yield(region, weights):
    result = 0
    for x, w in zip(region, weights):
        result += x * w
    return result
